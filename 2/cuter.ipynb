# %%
import cv2
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams['figure.figsize'] = (10,10)

# %%
im = cv2.imread("1/11.jpg")

plt.imshow(im)

print("Размер изображения:", str(im.shape[0]) + 'x' + str(im.shape[1]))
# Out:
# Размер изображения: 500x500

# %%
#Я нарисовала знаки, отсканировала их, и разбила на фрагменты 500х500p.
#Для того, чтобы избавиться от разлиновки попробуем взять изображения 44х44.

step = 50
line_num = 10
col_num = 10

# %%
for i in range(10):
    for j in range(10):
        cut = im[i*50 + 3:i*50 + step-3, j*50 + 3: j*50 + step-3]
        cv2.imwrite(str(i) + "x" + str(j) + ".jpg", cut)
